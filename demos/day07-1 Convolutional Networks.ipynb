# %% [markdown]
# # day07-1 - Convolutional Networks

# %%
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
# %matplotlib inline
from time import time
# Out:
# C:\Users\yoder\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
CIFAR = np.load('../data/CIFAR-10_train.npz')
CIFAR.files
# Out:
# ['train_labels', 'label_names', 'train_images']

# %%
images = CIFAR['train_images']
labels = CIFAR['train_labels']
names  = CIFAR['label_names']

# %%
images.shape
# Out:
# (50000, 32, 32, 3)

# %%
plt.imshow(images[11])

# %%
N = 10
M = 10
plt.figure(figsize=(15, 15))
plt.subplots_adjust(wspace=0.7, hspace=0.7)
for i in range(100):
    plt.subplot(10, 10, i+1)
    plt.axis('off')
    plt.imshow(images[i])
    plt.title (names[labels[i]])
plt.show()

# %%
# FInd an image for each label
plt.figure(figsize=(10, 10))
for i in range(len(names)):
    ix = np.argwhere(labels==i).flatten()[0]
    img = images[ix]
    plt.subplot(4, 4, i+1)
    plt.axis('off')
    plt.imshow(img, interpolation=None)
    plt.title(names[i])
plt.show()
