# %% [markdown]
# ## L11 - notMNIST Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
notMNIST = np.load('../data/notMNIST_train_100.npz')
notMNIST.keys()
# Out:
# ['train_images', 'train_labels']

# %%
notMNIST.files
# Out:
# ['train_images', 'train_labels']

# %%
notMNIST['train_images'].shape
# Out:
# (100, 28, 28)

# %%
notMNIST['train_labels'].shape
# Out:
# (100,)

# %%
images = notMNIST['train_images']
labels = notMNIST['train_labels']

# %%
my_image = notMNIST['train_images'][50]

# %%
plt.imshow(my_image, cmap='Greys_r')
plt.title("Test")
# Out:
# Text(0.5,1,'Test')

# %%
label_names = np.array(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'])
hist_label = pd.Series(label_names[labels]).value_counts()
hist_label
# Out:
# D    20
# G    14
# J    14
# I    12
# E     9
# A     8
# C     7
# H     7
# B     5
# F     4
# dtype: int64

# %%
label_names[labels[50]]
# Out:
# 'C'

# %%
N = 10
M = 10
plt.figure(figsize=(10, 10))
for i in range(M*N):
    plt.subplot(M, N, i+1)
    plt.imshow(images[i], cmap='Greys_r')
    plt.title(label_names[labels[i]])
    
plt.show()

# %%
char = 'I'
N = hist_label[char]
side = np.ceil(np.sqrt(N))
plt.figure(figsize=(10, 10))
k = 1
for i in range(100):
    if label_names[labels[i]] == char:
        plt.subplot(side, side, k)
        k += 1
        plt.imshow(images[i], cmap='Greys_r')
        plt.title(label_names[labels[i]])
plt.show()
