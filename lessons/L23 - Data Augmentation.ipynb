# %% [markdown]
# # Lession 23 - Data Augmenation

# %%
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def PlotImages(ix_start, num_img, rows, cols, X, P, label_names):
    plt.figure(figsize=(10, 10))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i in range(num_img):
        plt.subplot(rows, cols, i+1)
        plt.axis('off')
        plt.imshow(X[ix_start+i])
        plt.title(label_names[P[ix_start+i].argmax()])

# %%
label_names = ['cat', 'dog', 'other']
batch_size = 3
data_path = '/work/MA490_DeepLearning/Data/Dogs_vs_Cats/Small_Dataset/'
DataGenerator = (ImageDataGenerator(rescale=1./255,
                                   rotation_range=30,
                                   horizontal_flip=True,
                                   width_shift_range=0.5,
                                   height_shift_range=0.5,
                                   # zoom_range=0.5
                                   )
                 .flow_from_directory(
                    data_path,
                    target_size = (150, 150),
                    batch_size  = batch_size))
# Out:
# Found 4000 images belonging to 3 classes.

# %%
(X, P) = DataGenerator.next()
PlotImages(0, 3, 1, 3, X, P, label_names)

# %%
ix_start
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-5c5d5c6f1052> in <module>()
# ----> 1 ix_start
#
# NameError: name 'ix_start' is not defined

# %%
X.shape
# Out:
# (2, 150, 150, 3)

# %%
P.shape
# Out:
# (2, 3)

# %%
P
# Out:
# array([[0., 0., 1.],
#        [1., 0., 0.]], dtype=float32)
